# %% [markdown]
# <a href="https://colab.research.google.com/github/HiveCase/Deep-Learning/blob/main/Graded%20Assignment/DL_GA8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
from skimage import io

#Read and d i s p l a y t h e image

X = io.imread('https://caltech-prod.s3.amazonaws.com/main/images/feynman01-NEWS-WEB.width-600_tSwRQP5.jpg')

X = cv2.cvtColor(X, cv2.COLOR_RGB2GRAY)
plt.figure(figsize=(6,4))
plt.imshow(X,cmap='gray')
plt.show()


#D e f i n e k e r n e l s ( v a r y t h e s i z e by c h a n g i n m = 3
n=3
K = (1/(m*n))*np.ones((m,n))
O = cv2.filter2D(X,ddepth=-1,kernel=K)
plt.imshow(O,cmap='gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipykernel_17274/4049926894.py in <cell line: 0>()
#       6 #Read and d i s p l a y t h e image
#       7
# ----> 8 X = io.imread('https://caltech-prod.s3.amazonaws.com/main/images/feynman01-NEWS-WEB.width-600_tSwRQP5.jpg')
#       9
#      10 X = cv2.cvtColor(X, cv2.COLOR_RGB2GRAY)
#
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py in fixed_func(*args, **kwargs)
#     326                     kwargs[self.new_name] = deprecated_value
#     327
# --> 328             return func(*args, **kwargs)
#     329
#     330         if self.modify_docstring and func.__doc__ is not None:
#
# /usr/local/lib/python3.12/dist-packages/skimage/io/_io.py in imread(fname, as_gray, plugin, **plugin_args)
#      79             plugin = 'tifffile'
#      80
# ...

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from skimage import io
import requests
from io import BytesIO

url = "https://caltech-prod.s3.amazonaws.com/main/images/feynman01-NEWS-WEB.width-600_tSwRQP5.jpg"

headers = {
    "User-Agent": "Mozilla/5.0"
}

response = requests.get(url, headers=headers)
img = io.imread(BytesIO(response.content))

X = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

plt.figure(figsize=(6,4))
plt.imshow(X, cmap='gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_17274/70626813.py in <cell line: 0>()
#      13
#      14 response = requests.get(url, headers=headers)
# ---> 15 img = io.imread(BytesIO(response.content))
#      16
#      17 X = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
#
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py in fixed_func(*args, **kwargs)
#     326                     kwargs[self.new_name] = deprecated_value
#     327
# --> 328             return func(*args, **kwargs)
#     329
#     330         if self.modify_docstring and func.__doc__ is not None:
#
# /usr/local/lib/python3.12/dist-packages/skimage/io/_io.py in imread(fname, as_gray, plugin, **plugin_args)
#      80
#      81     with file_or_url_context(fname) as fname, _hide_plugin_deprecation_warnings():
# ...

# %%
  a1 = np.array([
      [0.8, 1.6],
      [0.8,1.6]
      ])
  a1
# Out:
# array([[0.8, 1.6],
#        [0.8, 1.6]])

# %%
def sig(X):
  return 1/(1+np.exp(-1*X))

# %%
h1 = sig(a1)
h1
# Out:
# array([[0.68997448, 0.83201839],
#        [0.68997448, 0.83201839]])

# %%
a2 = np.sum(h1)
a2
# Out:
# np.float64(3.043985732523074)

# %%
h2 = sig(a2)
h2
# Out:
# np.float64(0.9545221620677699)
